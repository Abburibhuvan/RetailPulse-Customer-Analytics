# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
rfm = pd.read_csv(r"E:/RetailPulse_Project/data/cleaned/rfm_customer_segment_large.csv")

# %%
rfm_features = rfm[["Recency","Frequency","Monetary"]]
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0       12346      326         12  77556.46        2        4        4
# 1       12347        2          8   4921.53        4        4        4
# 2       12348       75          5   2019.40        3        3        3
# 3       12349       19          4   4428.69        4        3        4
# 4       12350      310          1    334.40        2        1        1
#
#    RFM_Score         Segment
# 0        244     Big Spender
# 1        444        Champion
# 2        333  Loyal Customer
# 3        434  Loyal Customer
# 4        211   Lost Customer

# %%
scaler = StandardScaler()

# %%
rfm_scaled = scaler.fit_transform(rfm_features)

# %%
rfm_scaled[:5]
# Out:
# array([[ 0.59558355,  0.43899789,  5.16637792],
#        [-0.95227909,  0.13150188,  0.13612722],
#        [-0.60353226, -0.09912012, -0.06485654],
#        [-0.87106408, -0.17599412,  0.10199614],
#        [ 0.51914589, -0.40661612, -0.18154933]])

# %%
wcss = []

for k in range(1, 11):
    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    kmeans.fit(rfm_scaled)

    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,5))

plt.plot(range(1,11), wcss, marker="o")

plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")

plt.show()

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=10
)

kmeans.fit(rfm_scaled)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %%
rfm["Cluster"] = kmeans.labels_

rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R_Score  F_Score  M_Score  \
# 0       12346      326         12  77556.46        2        4        4
# 1       12347        2          8   4921.53        4        4        4
# 2       12348       75          5   2019.40        3        3        3
# 3       12349       19          4   4428.69        4        3        4
# 4       12350      310          1    334.40        2        1        1
#
#    RFM_Score         Segment  Cluster
# 0        244     Big Spender        0
# 1        444        Champion        0
# 2        333  Loyal Customer        0
# 3        434  Loyal Customer        0
# 4        211   Lost Customer        1

# %%
rfm["Cluster"].value_counts()
# Out:
# Cluster
# 0    3838
# 1    1998
# 3      38
# 2       4
# Name: count, dtype: int64

# %%
cluster_summary = rfm.groupby("Cluster")[[
    "Recency",
    "Frequency",
    "Monetary"
]].mean()

cluster_summary
# Out:
#             Recency   Frequency       Monetary
# Cluster
# 0         67.054455    7.267848    2921.080058
# 1        463.032032    2.212212     748.536998
# 2          3.500000  212.500000  428611.997500
# 3         24.263158  100.131579   77728.265579

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x=rfm["Frequency"],
    y=rfm["Monetary"],
    hue=rfm["Cluster"],
    palette="Set1"
)

plt.title("Customer Clusters")
plt.xlabel("Frequency")
plt.ylabel("Monetary")

plt.show()

# %%
rfm.to_csv(r"E:/RetailPulse_Project/data/cleaned/rfm_clustered_large.csv")
